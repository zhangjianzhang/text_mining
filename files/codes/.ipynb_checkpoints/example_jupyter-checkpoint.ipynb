# %% [markdown]
# # 1. 文字

# %% [markdown]
# HTML调色板：https://htmlcolorcodes.com/

# %% [markdown]
# <font size=2 style="color:#2ECC71">**示例**</font>：
#
# ```html
# <font size=2 style="color:#2ECC71">**示例**</font>
# ```

# %% [markdown]
# <font size=2 style="color:#2ECC71">**Example**</font>
#
# ```html
# <font size=2 style="color:#2ECC71">**Example**</font>
# ```

# %% [markdown]
# <font size=2 style="color:#FF0000">**注意**</font>：
#
# ```html
# <font size=2 style="color:#FF0000">**注意**</font>
# ```

# %% [markdown]
# <font size=2 style="color:#BA4A00">**练习**</font>：
#
# ```html
# <font size=2 style="color:#BA4A00">**练习**</font>
# ```

# %% [markdown]
# <font size=2 style="color:#9B59B6">**思考**</font>：
#
# ```html
# <font size=2 style="color:#9B59B6">**思考**</font>
# ```

# %% [markdown]
# <font size=2 style="color:#3498DB">**概念**</font>：
#
# ```html
# <font size=2 style="color:#3498DB">**概念**</font>
# ```

# %% [markdown]
# <font style="background:#00FF00"><strong>这是一个加粗高亮</strong></font>
#
# ```html
# <font style="background:#00FF00"><strong>这是一个加粗高亮</strong></font>
# ```

# %% [markdown]
# <font><em>这是一个斜体</em></font>
#
# ```html
# <font><em>这是一个斜体</em></font>
# ```

# %% [markdown]
# <center>我是居中文字</center>
#
# ```html
# <center>我是居中文字</center>
# ```

# %% [markdown]
# <center><font size=3 style="color:#BA4A00"><strong>我是居中加粗放大带颜色文字</strong></font></center>

# %% [markdown]
# ```html
# <center><font size=3 style="color:#BA4A00"><strong>我是居中加粗放大带颜色文字</strong></font></center>
# ```

# %% [markdown]
# # 2. 图片

# %% [markdown]
# <div align=center>
# <img src="https://github.com/zhangjianzhang/text_mining/blob/master/imgs/img-exp.jpg?raw=true">
# <br>
# <center><em><strong>我是原始的图片</strong></em></center>
# </div>
#
# ```html
# <div align=center>
# <img src="https://github.com/zhangjianzhang/text_mining/blob/master/imgs/img-exp.jpg?raw=true">
# <br>
# <center><em><strong>我是原始的图片</strong></em></center>
# </div>
# ```

# %% [markdown]
# <div align=center>
# <img width="850" height="550" src="https://github.com/zhangjianzhang/text_mining/blob/master/imgs/img-exp.jpg?raw=true">
# <br>
# <center><em><strong>我是指定尺寸后的图片</strong></em></center>
# </div>
#
# ```html
# <div align=center>
# <img width="850" height="550" src="https://github.com/zhangjianzhang/text_mining/blob/master/imgs/img-exp.jpg?raw=true">
# <br>
# <center><em><strong>我是指定尺寸后的图片</strong></em></center>
# </div>
# ```

# %% [markdown]
# # 3. 超链接

# %% [markdown]
# <a href="https://www.baidu.com/" target="_blank">点我</a>在 **新页面** 打开百度
#
# ```html
# <a href="https://www.baidu.com/" target="_blank">点我</a>在 **新页面** 打开百度
# ```

# %% [markdown]
# # 4. 公式

# %% [markdown]
# 使用Markdown输出LaTex数学公式：https://zhuanlan.zhihu.com/p/59412540

# %% [markdown]
# 内联输出：$f(x)=\frac{P(x)}{Q(x)}$
#
# `$f(x)=\frac{P(x)}{Q(x)}$`

# %% [markdown]
# 外联输出：
#
# $$f(x)=\frac{P(x)}{Q(x)}$$
#
# `$$f(x)=\frac{P(x)}{Q(x)}$$`

# %% [markdown]
# 矩阵：
#
# $$
#   \begin{matrix}
#    1 & 2 & 3 \\
#    4 & 5 & 6 \\
#    7 & 8 & 9
#   \end{matrix}
# $$
#
# ```tex
# $$
#   \begin{matrix}
#    1 & 2 & 3 \\
#    4 & 5 & 6 \\
#    7 & 8 & 9
#   \end{matrix}
# $$
# ```

# %% [markdown]
# <br>
# <center><font size=3 style="color:#D68910"><strong>未完待续</strong></font></center>
