# %% [markdown]
# # 4.   Writing Structured Programs

# %% [markdown]
# ## 4.1   Back to the Basics

# %% [markdown]
# - Assignment
#
# - Equality
#
# - Conditionals

# %% [markdown]
# ## 4.2   Sequences

# %% [markdown]
# - Operating on Sequence Types
#
# - Combining Different Sequence Types
#
# - Generator Expressions

# %% [markdown]
# ## 4.3   Questions of Style

# %% [markdown]
# - Python Coding Style
#
# - Procedural vs Declarative Style
#
# - Some Legitimate Uses for Counters

# %% [markdown]
# ## 4.4   Functions: The Foundation of Structured Programming

# %% [markdown]
# - Function Inputs and Outputs
#
# - Parameter Passing
#
# - Variable Scope
#
# - Checking Parameter Types
#
# - Functional Decomposition
#
# - Documenting Functions

# %% [markdown]
# ## 4.5   Doing More with Functions

# %% [markdown]
# - Functions as Arguments
#
# - Accumulative Functions
#
# - Higher-Order Functions
#
# - Named Arguments

# %% [markdown]
# ## 4.6   Program Development

# %% [markdown]
# - Structure of a Python Module
#
# - Multi-Module Programs
#
# - Sources of Error
#
# - Debugging Techniques
#
# - Defensive Programming

# %% [markdown]
# The above content is out of the scope of our course and you can learn it by yourself:
#
# - Refer to the content in <a href="https://www.nltk.org/book/ch04.html" target="_blank">Chapter 4</a> of *Natural Language Processing with Python*
#
# - I strongly recommend you to learn the related lectures in my *programming basics* course: <a href="https://zhangjianzhang.github.io/programming_basics/" target="_blank">Course Website</a>

# %% [markdown]
# ## 4.7   Algorithm Design

# %% [markdown]
# ### 4.7.1 divide-and-conquer

# %% [markdown]
# We attack a problem of size n by **dividing it into two problems of size n/2**, solve these problems, and **combine their results into a solution of the original problem**.

# %% [markdown]
# <font size=2 style="color:#2ECC71">**Example**</font>
#
# **Merge Sort (归并排序)**

# %% [markdown]
# 归并排序是采用分治法（Divide and Conquer）的一个非常典型的应用。
#
# Reference:
#
# - https://www.cnblogs.com/pythonbao/p/10800699.html
#
# - https://www.runoob.com/python3/python-merge-sort.html

# %% [markdown]
# 1. 自顶向下，递归地**二等分**列表，直到不可分为止，即每个子列表只包含一个元素

# %% [markdown]
# <div align=center>
# <img width="1000" height="750" src="https://raw.githubusercontent.com/zhangjianzhang/text_mining/master/files/codes/lecture_4/split.png">
# <br>
# <center><em><strong>递归划分列表</strong></em></center>
# </div>

# %%
def merge_sort(arr):
    if len(arr) == 1:
        return arr
    else:
        length = len(arr)
        left_arr = arr[:length//2]
        right_arr = arr[length//2:]
        print('split',arr,'--->',left_arr, right_arr)
        return sort_list(merge_sort(left_arr), merge_sort(right_arr))

# %% [markdown]
# 2. 自底向上，递归地**排序**、**合并**子列表

# %% [markdown]
# <div align=center>
# <img width="1000" height="750" src="https://raw.githubusercontent.com/zhangjianzhang/text_mining/master/files/codes/lecture_4/merge.png">
# <br>
# <center><em><strong>递归排序、合并列表</strong></em></center>
# </div>

# %% [markdown]
# **已排序子列表**`[11, 18]`和`[6, 9, 10]`的排序合并过程如下：
#
# 1. 对比第一个元素，$11 < 6$，6放入结果列表中，结果列表为`[6]`；
#
# 2. 两个子列表变为`[11, 18]`和`[9, 10]`；
#
# 3. 对比第一个元素$11 > 9$，9放入结果列表中，结果列表为`[6, 9]`；
#
# 4. 两个子列表变为`[11, 18]`和`[10]`；
#
# 5. 对比第一个元素$11 > 10$，10放入结果列表中，结果列表为`[6, 9, 10]`；
#
# 6. 两个子列表变为`[11, 18]`和`[]`；
#
# 7. 第一个子列表有序，第二个子列表为空，将第一个子列表加入结果列表，结果列表为`[6, 9, 10, 11, 18]`。

# %%
from copy import deepcopy

def sort_list(left, right):
    
    l, r = deepcopy(left), deepcopy(right)
    
    result = []
    while len(left) > 0 and len(right) > 0:
        if left[0] < right[0]:
            result.append(left.pop(0))
        else:
            result.append(right.pop(0))
    
    result += left
    result += right
    
    print('merge',l, r,'--->',result)
    
    return result

# %%
arr = [11, 18, 10, 9, 6]

# %%
merge_sort(arr)
# Out:
# split [11, 18, 10, 9, 6] ---> [11, 18] [10, 9, 6]
# split [11, 18] ---> [11] [18]
# merge [11] [18] ---> [11, 18]
# split [10, 9, 6] ---> [10] [9, 6]
# split [9, 6] ---> [9] [6]
# merge [9] [6] ---> [6, 9]
# merge [10] [6, 9] ---> [6, 9, 10]
# merge [11, 18] [6, 9, 10] ---> [6, 9, 10, 11, 18]
# [6, 9, 10, 11, 18]

# %%
arr = [1,4,2]

# %%
merge_sort(arr)
# Out:
# split [1, 4, 2] ---> [1] [4, 2]
# split [4, 2] ---> [4] [2]
# merge [4] [2] ---> [2, 4]
# merge [1] [2, 4] ---> [1, 2, 4]
# [1, 2, 4]

# %% [markdown]
# ### 4.7.2 Recursion

# %% [markdown]
# <font size=2 style="color:#2ECC71">**Example**</font>
#
# Let's count the size of the hypernym hierarchy rooted at a given synset s. (以同义词集s为根的WordNet子树所包含的节点个数)

# %% [markdown]
# <div align=center>
# <img width="550" height="350" src="https://raw.githubusercontent.com/zhangjianzhang/text_mining/master/files/codes/lecture_4/tree_noeds.png">
# <br>
# <center><em><strong>计算树的节点数</strong></em></center>
# </div>

# %%
# 采用字典结构存储上图中的树
n1 = {
        'n2':{},
        'n3':{
            'n4':{
                'n6':{},
                'n7':{},
                'n8':{}
            },
            'n5':{}
        }
    }

# %% [markdown]
# 两种基本情况：
#
# 1. 叶子节点（没有子节点），如，`'n5':{}`
#
# 2. 非叶子节点（有至少一个子节点），如，`'n4':{'n6':{}, 'n7':{}, 'n8':{}}`

# %%
# 第一种递归写法
def tree_nodes_count(tree_dict):
    return 1 + sum(tree_nodes_count(v) for v in tree_dict.values())

# %%
# 逐层遍历计数
def tree_nodes_count_alt(tree_dict):
    trees = [tree_dict] 
    total = 0
    while trees:
        total += len(trees)
        trees = [value for tree in trees for value in tree.values()]
    return total

# %%
nn = {'n1':{'n2':{'n3':{}}}}

# %%
tree_nodes_count(nn)
# Out:
# 4

# %%
tree_nodes_count_alt(nn)
# Out:
# 4

# %%
tree_nodes_count(n1)
# Out:
# 8

# %%
tree_nodes_count_alt(n1)
# Out:
# 8

# %%
n1
# Out:
# {'n2': {}, 'n3': {'n4': {'n6': {}, 'n7': {}, 'n8': {}}, 'n5': {}}}

# %%
tree_nodes_count({'n2': {}, 'n3':{}})
# Out:
# 3

# %%
# 递归遍历计数
def size1(s):
    return 1 + sum(size1(child) for child in s.hyponyms())

# %%
# 逐层遍历计数
def size2(s):
    layer = [s] # The first layer is the synset itself
    total = 0
    # it computes the next layer by finding the hyponyms of everything in the last layer
    while layer:
        total += len(layer)
        layer = [h for c in layer for h in c.hyponyms()]
    return total

# %%
from nltk.corpus import wordnet as wn

# %%
dog = wn.synset('dog.n.01')

# %%
dog.hyponyms()
# Out:
# [Synset('basenji.n.01'),
#  Synset('corgi.n.01'),
#  Synset('cur.n.01'),
#  Synset('dalmatian.n.02'),
#  Synset('great_pyrenees.n.01'),
#  Synset('griffon.n.02'),
#  Synset('hunting_dog.n.01'),
#  Synset('lapdog.n.01'),
#  Synset('leonberg.n.01'),
#  Synset('mexican_hairless.n.01'),
#  Synset('newfoundland.n.01'),
#  Synset('pooch.n.01'),
#  Synset('poodle.n.01'),
#  Synset('pug.n.01'),
#  Synset('puppy.n.01'),
#  Synset('spitz.n.01'),
#  Synset('toy_dog.n.01'),
#  Synset('working_dog.n.01')]

# %%
size1(dog)
# Out:
# 190

# %%
size2(dog)
# Out:
# 190

# %% [markdown]
# <font size=2 style="color:#2ECC71">**Example**</font>
#
# A **letter trie** is a data structure that can be used for indexing a lexicon.
#
# 字典树是一种索引词典的数据结构。

# %% [markdown]
# <div align=center>
# <img width="550" height="350" src="https://raw.githubusercontent.com/zhangjianzhang/text_mining/master/files/codes/lecture_4/trie.gif">
# <br>
# <center><em><strong>字典树示意图</strong></em></center>
# </div>

# %% [markdown]
# Recursively build a letter trie with Python dictionaries.

# %%
def insert(trie, key, value):
    if key:
        first, rest = key[0], key[1:]
        if first not in trie:
            trie[first] = {}
        insert(trie[first], rest, value)
    else:
        trie['value'] = value

# %%
import pprint

# %%
trie = {}

# %%
insert(trie, 'bear', '熊')

# %%
insert(trie, 'bell', '钟')

# %%
pprint.pprint(trie, width=40)
# Out:
# {'b': {'e': {'a': {'r': {'value': '熊'}},
#              'l': {'l': {'value': '钟'}}}}}

# %%
insert(trie, 'bid', '出价')

# %%
insert(trie, 'bull', '公牛')

# %%
insert(trie, 'buy', '买')

# %%
pprint.pprint(trie, width=40)
# Out:
# {'b': {'e': {'a': {'r': {'value': '熊'}},
#              'l': {'l': {'value': '钟'}}},
#        'i': {'d': {'value': '出价'}},
#        'u': {'l': {'l': {'value': '公牛'}},
#              'y': {'value': '买'}}}}

# %%
insert(trie, 'sell', '卖')

# %%
insert(trie, 'stock', '股票')

# %%
insert(trie, 'stop', '停止')

# %%
trie = dict(trie)

# %%
trie['b']['u']['y']['value']
# Out:
# '买'

# %%
import pprint

pprint.pprint(trie, width=40)
# Out:
# {'b': {'e': {'a': {'r': {'value': '熊'}},
#              'l': {'l': {'value': '钟'}}},
#        'i': {'d': {'value': '出价'}},
#        'u': {'l': {'l': {'value': '公牛'}},
#              'y': {'value': '买'}}},
#  's': {'e': {'l': {'l': {'value': '卖'}}},
txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv925_9459.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv926_18471.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv927_11471.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv928_9478.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv929_1841.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv930_14949.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv931_18783.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv932_14854.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv933_24953.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv934_20426.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv935_24977.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv936_17473.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv937_9816.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv938_10706.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv939_11247.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv940_18935.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv941_10718.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv942_18509.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv943_23547.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv944_15042.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv945_13012.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv946_20084.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv947_11316.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv948_25870.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv949_21565.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv950_13478.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv951_11816.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv952_26375.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv953_7078.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv954_19932.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv955_26154.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv956_12547.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv957_9059.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv958_13020.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv959_16218.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv960_28877.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv961_5578.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv962_9813.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv963_7208.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv964_5794.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv965_26688.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv966_28671.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv967_5626.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv968_25413.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv969_14760.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv970_19532.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv971_11790.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv972_26837.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv973_10171.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv974_24303.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv975_11920.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv976_10724.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv977_4776.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv978_22192.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv979_2029.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv980_11851.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv981_16679.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv982_22209.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv983_24219.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv984_14006.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv985_5964.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv986_15092.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv987_7394.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv988_20168.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv989_17297.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv990_12443.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv991_19973.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv992_12806.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv993_29565.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv994_13229.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv995_23113.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv996_12447.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv997_5152.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv998_15691.txt'),
#  FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv999_14636.txt'),
#  ...]

# %%
print("Building Index...")
idx = nltk.Index((w, f) for f in files for w in raw(f).split())
# Out:
# Building Index...

# %%
help(idx)
# Out:
# Help on Index in module nltk.util object:
#
# class Index(collections.defaultdict)
#  |  Index(pairs)
#  |
#  |  Method resolution order:
#  |      Index
#  |      collections.defaultdict
#  |      builtins.dict
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, pairs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from collections.defaultdict:
#  |
#  |  __copy__(...)
#  |      D.copy() -> a shallow copy of D.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __missing__(...)
#  |      __missing__(key) # Called by __getitem__ for missing key; pseudo-code:
#  |      if self.default_factory is None: raise KeyError((key,))
#  |      self[key] = value = self.default_factory()
#  |      return value
#  |
#  |  __or__(self, value, /)
#  |      Return self|value.
#  |
#  |  __reduce__(...)
#  |      Return state information for pickling.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __ror__(self, value, /)
#  |      Return value|self.
#  |
#  |  copy(...)
#  |      D.copy() -> a shallow copy of D.
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods inherited from collections.defaultdict:
#  |
#  |  __class_getitem__(...) from builtins.type
#  |      See PEP 585
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from collections.defaultdict:
#  |
#  |  default_factory
#  |      Factory for default value called by __missing__().
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from builtins.dict:
#  |
#  |  __contains__(self, key, /)
#  |      True if the dictionary has the specified key, else False.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __ior__(self, value, /)
#  |      Return self|=value.
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __len__(self, /)
#  |      Return len(self).
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __reversed__(self, /)
#  |      Return a reverse iterator over the dict keys.
#  |
#  |  __setitem__(self, key, value, /)
#  |      Set self[key] to value.
#  |
#  |  __sizeof__(...)
#  |      D.__sizeof__() -> size of D in memory, in bytes
#  |
#  |  clear(...)
#  |      D.clear() -> None.  Remove all items from D.
#  |
#  |  get(self, key, default=None, /)
#  |      Return the value for key if key is in the dictionary, else default.
#  |
#  |  items(...)
#  |      D.items() -> a set-like object providing a view on D's items
#  |
#  |  keys(...)
#  |      D.keys() -> a set-like object providing a view on D's keys
#  |
#  |  pop(...)
#  |      D.pop(k[,d]) -> v, remove specified key and return the corresponding value.
#  |
#  |      If key is not found, default is returned if given, otherwise KeyError is raised
#  |
#  |  popitem(self, /)
#  |      Remove and return a (key, value) pair as a 2-tuple.
#  |
#  |      Pairs are returned in LIFO (last-in, first-out) order.
#  |      Raises KeyError if the dict is empty.
#  |
#  |  setdefault(self, key, default=None, /)
#  |      Insert key with a value of default if key is not in the dictionary.
#  |
#  |      Return the value for key if key is in the dictionary, else default.
#  |
#  |  update(...)
#  |      D.update([E, ]**F) -> None.  Update D from dict/iterable E and F.
#  |      If E is present and has a .keys() method, then does:  for k in E: D[k] = E[k]
#  |      If E is present and lacks a .keys() method, then does:  for k, v in E: D[k] = v
#  |      In either case, this is followed by: for k in F:  D[k] = F[k]
#  |
#  |  values(...)
#  |      D.values() -> an object providing a view on D's values
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods inherited from builtins.dict:
#  |
#  |  fromkeys(iterable, value=None, /) from builtins.type
#  |      Create a new dictionary with keys from iterable and values set to value.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from builtins.dict:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from builtins.dict:
#  |
#  |  __hash__ = None

# %%
list(idx.items())[:2]
# Out:
# [('plot',
#   [FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv000_29416.txt'),
#    FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv002_17424.txt'),
#    FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv002_17424.txt'),
#    FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv004_12641.txt'),
#    FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv005_29357.txt'),
#    FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv007_4992.txt'),
#    FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv009_29417.txt'),
#    FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv009_29417.txt'),
#    FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv010_29063.txt'),
#    FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv013_10494.txt'),
#    FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv013_10494.txt'),
#    FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/c
txt'),
#    FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv637_13682.txt'),
#    FileSystemPathPointer('/usr/local/share/nltk_data/corpora/movie_reviews/neg/cv637_13682.txt'),
#    ...])]

# %%
# query = ''
# while query != "quit":
#     query = input("query> ")
#     if query in idx:
#         for doc in idx[query]:
#             print(snippet(doc, query))
#     else:
#         print("Not found")

# %% [markdown]
# <font size=2 style="color:#2ECC71">**Example**</font>
#
# A more subtle example of a space-time tradeoff involves **replacing the tokens of a corpus with integer identifiers**.

# %% [markdown]
# - Create a vocabulary for the corpus, a dict in which each word is stored once, so that we can look up any word to find its identifier.
#
# - Each document is preprocessed, so that a list of words becomes a list of integers.
#
# - Any language models can now work with integers.

# %%
def preprocess(tagged_corpus):
    # 使用集合存储词表和标签表
    words = set()
    tags = set()
    for sent in tagged_corpus:
        for word, tag in sent:
            words.add(word)
            tags.add(tag)
    word2idx = dict((w, i) for (i, w) in enumerate(words))
    tag2idx = dict((t, i) for (i, t) in enumerate(tags))
    return word2idx, tag2idx

# %%
from nltk.corpus import brown

# %%
tagged_brown = brown.tagged_sents()

# %%
# [[(word2idx, tag2idx[t]) for (w, t) in sent] for sent in tagged_corpus]

# %%
word2idx, tag2idx = preprocess(tagged_brown)

# %%
word2idx
# Out:
# {'Bucky': 0,
#  'intercepts': 1,
#  'peanuts': 2,
#  'parasols': 3,
#  'cosmopolitan': 4,
#  'dimethylglyoxime': 5,
#  "Britain's": 6,
#  'respite': 7,
#  'restrict': 8,
#  'BG': 9,
#  'Channel': 10,
#  'diminutive': 11,
#  'invaded': 12,
#  'vaster': 13,
#  'manifesting': 14,
#  'if': 15,
#  '1838': 16,
#  'undergone': 17,
#  'hypnotized': 18,
#  'Bead': 19,
#  'undedicated': 20,
#  'eighty-one': 21,
#  'bloomed': 22,
#  'Taylors': 23,
#  "Tillie's": 24,
#  'worshippers': 25,
#  'Belle': 26,
#  'quickest': 27,
#  'receptionist': 28,
#  '1803': 29,
#  'Assn.': 30,
#  'grasping': 31,
#  'unpremeditated': 32,
#  'ferret': 33,
#  'inscrutable': 34,
#  'aquam': 35,
#  "fall's": 36,
#  'Rooms': 37,
#  "County's": 38,
#  'sinuously': 39,
#  'pooled': 40,
#  'Necklace': 41,
#  'Detroit': 42,
#  'eighty-five': 43,
#  'Workers': 44,
#  'kitchenette': 45,
#  'intramural': 46,
#  'idealism': 47,
#  'Seaquarium': 48,
#  'warmed-over': 49,
#  'whiteness': 50,
#  'innings': 51,
#  'inadvertent': 52,
#  'placating': 53,
#  'becalmed': 54,
#  "football's": 55,
#  'glinting': 56,
#  'tariff-free': 57,
#  'Interama': 58,
#  'doorkeeper': 59,
#  'benefit': 60,
#  'hatching': 61,
#  'anchored': 62,
#  'iniquitous': 63,
#  'Pa': 64,
#  'Baslot': 65,
#  'vacated': 66,
#  'pike': 67,
#  'purpose': 68,
#  'through': 69,
#  'Hinduism': 70,
#  'porter': 71,
#  'thermodynamics': 72,
#  'clutching': 73,
#  'riot': 74,
#  'patients': 75,
#  'sun-inflamed': 76,
#  'virtually': 77,
#  'walnuts': 78,
#  'Energy': 79,
#  'Hockaday': 80,
#  'slugged': 81,
#  'moon-washed': 82,
#  'contended': 83,
#  'harvesting': 84,
#  'Morris': 85,
#  'Sic': 86,
#  'coals': 87,
#  "Hesperus'": 88,
#  'necktie': 89,
#  'denial': 90,
#  'doomsday': 91,
#  'cost-accounting': 92,
#  'hubbub': 93,
#  "Kennedy's": 94,
#  'Rainy': 95,
#  'subcontinent': 96,
#  'suggesting': 97,
#  'mirrored': 98,
#  'Rickards': 99,
#  '$7.20': 100,
#  'polecat': 101,
#  'sneaked': 102,
#  'opener': 103,
#  'melody': 104,
#  'Harvest': 105,
#  'evident': 106,
#  'appeal': 107,
#  "beggar's": 108,
#  'Yeller': 109,
#  'dispossession': 110,
#  'interchangeable': 111,
#  'stainless': 112,
#  'reappears': 113,
#  'fringed-wrapped': 114,
#  'hydrophilic': 115,
#  'forgitful': 116,
#  "Estella's": 117,
#  'generosity': 118,
#  "Newton's": 119,
#  'Thevenow': 120,
#  'Turner': 121,
#  'Wetter': 122,
#  'sins': 123,
#  'Simms': 124,
#  'Bayezit': 125,
#  '$10.1': 126,
#  'unsloped': 127,
#  'RDW': 128,
#  '29': 129,
#  '10.8%': 130,
#  'snort': 131,
#  'quite': 132,
#  'reorganized': 133,
#  'Thakhek': 134,
#  'befell': 135,
#  'exasperated': 136,
#  "Ryc'": 137,
#  '4-1/2%': 138,
#  'wound': 139,
#  '65-year-old': 140,
#  'posted': 141,
#  'Rockhall': 142,
#  '$550': 143,
#  'plasm': 144,
#  'Tucson': 145,
#  'Car': 146,
#  'grottoes': 147,
#  'Ye': 148,
#  'encased': 149,
#  'Lincoln': 150,
#  "'bout": 151,
#  'contortion': 152,
#  'entry-limit': 153,
#  'self-exile': 154,
#  'piezoelectric': 155,
#  'French': 156,
#  'bloodshed': 157,
#  'paraxial': 158,
#  'baying': 159,
#  'disproportionate': 160,
#  'detailed': 161,
#  'Copeland': 162,
#  'grimly': 163,
#  'spa': 164,
#  'demagnification': 165,
#  "Shartzer's": 166,
#  'embattled': 167,
#  'mildly': 168,
#  'Tory': 169,
#  'protestations': 170,
#  "l's": 171,
#  'occidental': 172,
#  'panicky': 173,
#  'Bottom': 174,
#  'Believe': 175,
#  'Presidents': 176,
#  "Oats's": 177,
#  'dustbin': 178,
#  'Grimesby': 179,
#  "Bartoli's": 180,
#  'Oklahoma!': 181,
#  'Dollar-De': 182,
#  'synergism': 183,
#  'incinerator': 184,
#  '19': 185,
#  'presumptions': 186,
#  'cashmere': 187,
#  'touching': 188,
#  'gyros': 189,
#  'milling': 190,
#  'salamander': 191,
#  '1945': 192,
#  'rash': 193,
#  'cratered': 194,
#  'kickbacks': 195,
#  'chalk-white': 196,
#  'gnaw': 197,
#  'prodding': 198,
#  'Taxation': 199,
#  'intruders': 200,
#  'work-weary': 201,
#  'Stepanovich': 202,
#  'annum': 203,
#  'Report': 204,
#  'furlongs': 205,
#  'respecting': 206,
#  'Koehler': 207,
#  'Cassius': 208,
#  '64-page': 209,
#  '$66,000': 210,
#  'futile': 211,
#  'planters': 212,
#  "pleasin'": 213,
#  'dumb': 214,
#  'Arch': 215,
#  'unspoken': 216,
#  'mutations': 217,
#  'Want': 218,
#  'knee-type': 219,
#  'safe': 220,
#  'visions': 221,
#  'compilations': 222,
#  'concentrations': 223,
#  'Export': 224,
#  'intratissue': 225,
#  'living-room': 226,
#  'confreres': 227,
#  'clergymen': 228,
#  'fadeout': 229,
#  'revolution': 230,
#  'unfalteringly': 231,
#  'Urich': 232,
#  'easily': 233,
#  'aptness': 234,
#  'Christmas': 235,
#  'ribbon': 236,
#  'New-York': 237,
#  'Ranger': 238,
#  'bounding': 239,
#  'dressings': 240,
#  'interdenominational': 241,
#  'utopias': 242,
#  'flatiron': 243,
#  'inspecting': 244,
#  '90-day': 245,
#  'Blueprints': 246,
#  'courage': 247,
#  'Opportunity': 248,
#  'Welton': 249,
#  'sprung': 250,
#  'Ditmar': 251,
#  'thumb-': 252,
#  'Wister': 253,
#  'Based': 254,
#  'Business': 255,
#  'corn-belt': 256,
#  'conning': 257,
#  'enrolling': 258,
#  "Doolin's": 259,
#  'establishes': 260,
#  'regulator': 261,
#  'Montevideo': 262,
#  'dark-blue': 263,
#  'tooling': 264,
#  'hog': 265,
#  'nodding': 266,
#  'Tolerance': 267,
#  'numerology': 268,
#  'foreign': 269,
#  'ambrosial': 270,
#  'Forge': 271,
#  'widthwise': 272,
#  'ripened': 273,
#  'woomera': 274,
#  'Tragedy': 275,
#  'Methyl': 276,
#  'knotty': 277,
#  '704': 278,
#  'Adjusted': 279,
#  'midshipmen': 280,
#  'forbids': 281,
#  'calling': 282,
#  'erratic': 283,
#  'Catastrophe': 284,
#  'single-valued': 285,
#  "R's": 286,
#  'Ingbar': 287,
#  'Literature': 288,
#  'Middle-South': 289,
#  'discontinue': 290,
#  'Locker-room': 291,
#  'Sickness': 292,
#  'shipbuilding': 293,
#  'Tims': 294,
#  'Lark': 295,
#  'co-operating': 296,
#  'thoroughness': 297,
#  'Episcopal': 298,
#  'friendliness': 299,
#  'railroad': 300,
#  'some': 301,
#  'Saadi': 302,
#  'logging': 303,
#  'Frenchmen': 304,
#  'Bellini': 305,
#  'half-reluctant': 306,
#  'best-tempered': 307,
#  "Massachusetts'": 308,
#  'incomprehensible': 309,
#  'chin-ups': 310,
#  'constitutes': 311,
#  'likely': 312,
#  'Clean': 313,
#  'Arata': 314,
#  'photosensitive': 315,
#  'special-interest': 316,
#  'molar': 317,
#  'Anglo-Protestant': 318,
#  'Moune': 319,
#  'full-grown': 320,
#  'tsh': 321,
#  'paradoxical': 322,
#  'Industrial': 323,
#  'conclusive': 324,
#  'reeking': 325,
#  'tubules': 326,
#  'Af': 327,
#  'Speed': 328,
#  'hundred-odd': 329,
#  'rocket-bombs': 330,
#  'occupational': 331,
#  'fixers': 332,
#  'States-Yugoslav': 333,
#  'Webber': 334,
#  'clubhouse': 335,
#  'Ten': 336,
#  'yanking': 337,
#  'hydrated': 338,
#  'Vineyard': 339,
#  'coastal': 340,
#  "convict's": 341,
#  'name': 342,
#  "morning's": 343,
#  'numbingly': 344,
#  'tear-soaked': 345,
#  'patrician': 346,
#  'ironies': 347,
#  'Niggertown': 348,
#  'devise': 349,
#  'style': 350,
#  'omits': 351,
#  'Telemann': 352,
#  '$65': 353,
#  'Confusion': 354,
#  'succor': 355,
#  'trouble': 356,
#  'festivities': 357,
#  'Wilde': 358,
#  'franks': 359,
#  'Australian': 360,
#  '1.8': 361,
#  'collaborators': 362,
#  "region's": 363,
#  "pauper's": 364,
#  'steeped': 365,
#  'sediment': 366,
#  'detachable': 367,
#  "Martin's": 368,
#  'algebraic': 369,
#  'Taxpayers': 370,
#  'exorbitant': 371,
#  "Pawtucket's": 372,
#  'happiness': 373,
#  'moons': 374,
#  'Andrei': 375,
#  'Benson': 376,
#  'light-weight': 377,
#  'nostalgia': 378,
#  'hammered': 379,
#  'Method': 380,
#  'wall-switch': 381,
#  'nest': 382,
#  'over-pretended': 383,
#  'tombs': 384,
#  'illegitimate': 385,
#  'godliness': 386,
#  'sidewalks': 387,
#  'Republics': 388,
#  'expressible': 389,
#  'tug': 390,
#  '795,586': 391,
#  'muffled': 392,
#  'Thornburg': 393,
#  'commendable': 394,
#  'hindsight': 395,
#  'Everybody': 396,
#  'freedoms': 397,
#  'a-gracious': 398,
#  'open': 399,
#  'bathtubs': 400,
#  'well-trained': 401,
#  'unilaterally': 402,
#  'thicker': 403,
#  'tack': 404,
#  'Equate': 405,
#  'Paragraph': 406,
#  'wedge-shaped': 407,
#  'backyard': 408,
#  '2.16': 409,
#  "cousins'": 410,
#  "hotelman's": 411,
#  'unstrung': 412,
#  'balconies': 413,
#  'rankles': 414,
#  'Diaghileff': 415,
#  'realms': 416,
#  'palisades': 417,
#  'bicycle': 418,
#  'training': 419,
#  'appallingly': 420,
#  'Bah': 421,
#  'weddings': 422,
#  '1:35': 423,
#  'school-age': 424,
#  'Licenses': 425,
#  'Pioneers': 426,
#  'imperious': 427,
#  'simulation': 428,
#  'captions': 429,
#  'stores': 430,
#  'Vamp': 431,
#  'Luis': 432,
#  'Germanized': 433,
#  "Marquis'": 434,
#  'resolves': 435,
#  'pastel': 436,
#  'sponge': 437,
#  '270': 438,
#  'arid': 439,
#  'trans-Atlantic': 440,
#  'universally': 441,
#  'Yamabe': 442,
#  '67': 443,
#  'Lover': 444,
#  'snap': 445,
#  'sheer': 446,
#  'Marcus': 447,
#  'invigorating': 448,
#  'parading': 449,
#  'Marinas': 450,
#  'drawers': 451,
#  'Dissect': 452,
#  'underway': 453,
#  '1811': 454,
#  'Frankly': 455,
#  'Policy': 456,
#  'congregational': 457,
#  'registrants': 458,
#  '1307': 459,
#  'exploiters': 460,
#  'Theory': 461,
#  'distinctly': 462,
#  'prevents': 463,
#  'assertive': 464,
#  'badge-toter': 465,
#  "Emperor's": 466,
#  'workers': 467,
#  'illumined': 468,
#  'overwhelming': 469,
#  'Igbo': 470,
#  'sweater': 471,
#  'contradicted': 472,
#  '589': 473,
#  'ovation': 474,
#  'instruction': 475,
#  "mob's": 476,
#  'Archuleta': 477,
#  'instructing': 478,
#  'Atlanta': 479,
#  'Language': 480,
#  'abounds': 481,
#  'Whosever': 482,
#  'babyhood': 483,
#  '61': 484,
#  'Poltava': 485,
#  'benzene': 486,
#  'implored': 487,
#  'disturbance': 488,
#  'torquer': 489,
#  'villainous': 490,
#  '25%': 491,
#  'hung': 492,
#  'day-to-day': 493,
#  'swam': 494,
#  'chronically': 495,
#  'transporting': 496,
#  '250-275': 497,
#  'Portrait': 498,
#  'cattle': 499,
#  'nonism': 500,
#  'alkali': 501,
#  'gearing': 502,
#  "Burlington's": 503,
#  'wrongful': 504,
#  "Capone's": 505,
#  'immunity': 506,
#  'calumny': 507,
#  '80th': 508,
#  'folly': 509,
#  'implication': 510,
#  'Abbot': 511,
#  'pug-nosed': 512,
#  'photoluminescence': 513,
#  'ale': 514,
#  'disking': 515,
#  'short': 516,
#  'finned': 517,
#  'Salida': 518,
#  'Turkey': 519,
#  "athletes'": 520,
#  'gaited': 521,
#  'wooded': 522,
#  'bankers': 523,
#  'challenge': 524,
#  'A5': 525,
#  'maw': 526,
#  'gyro-stabilized': 527,
#  'Vineyards': 528,
#  'Handbook': 529,
#  '211': 530,
#  'turnery': 531,
#  'architectonic': 532,
#  'transcultural': 533,
#  'value': 534,
#  'Future': 535,
#  'Rumanian': 536,
#  'Designed': 537,
#  'fortress': 538,
#  'Mattathias': 539,
#  'purposefully': 540,
#  'Johansen': 541,
#  'Felix': 542,
#  'note': 543,
#  '7th': 544,
#  'doings': 545,
#  'Systems': 546,
#  'donation': 547,
#  'Apocalypse': 548,
#  'Elburn': 549,
#  'Khmer': 550,
#  'child-bearing': 551,
#  'Cherry': 552,
#  'Alfa': 553,
#  'fundamental': 554,
#  'unperformed': 555,
#  'researchers': 556,
#  'exclamations': 557,
#  'sluggers': 558,
#  'Hard': 559,
#  'wrong-headed': 560,
#  'film': 561,
#  'coughing': 562,
#  'nobility': 563,
#  'Arabians': 564,
#  'Dow-Jones': 565,
#  'suffer': 566,
#  'king': 567,
#  'honorary': 568,
#  'score': 569,
#  'lifeboats': 570,
#  'incantation': 571,
#  'secrets': 572,
#  'Lavaughn': 573,
#  'mixing': 574,
#  'Estella': 575,
#  'interactions': 576,
#  'rasped': 577,
#  "Sangallo's": 578,
#  'juste': 579,
#  'Geisha': 580,
#  'bureau': 581,
#  'purposes': 582,
#  'besmirching': 583,
#  'rubble': 584,
#  'Pengally': 585,
#  'Amendments': 586,
#  'Moving': 587,
#  '28th': 588,
#  'bald': 589,
#  'Wooden': 590,
#  'three-wood': 591,
#  'alphabetical': 592,
#  'one-night': 593,
#  'commute': 594,
#  'speech-making': 595,
#  'overestimated': 596,
#  'childishly': 597,
#  'remote': 598,
#  'Dineen': 599,
#  'Pietism': 600,
#  'Heart-measuring': 601,
#  '3-hp.': 602,
#  'dig': 603,
#  'arch-heretic': 604,
#  'Lobby': 605,
#  'Buell': 606,
#  'retranslated': 607,
#  'ceramic': 608,
#  'Cohn': 609,
#  'Squatting': 610,
#  'Stephens': 611,
#  'hypoactive': 612,
#  'indistinct': 613,
#  'bronc': 614,
#  'paw': 615,
#  'cocaine': 616,
#  'installment': 617,
#  'Bruxelles': 618,
#  'Adrar': 619,
#  'frizzling': 620,
#  'Sonar': 621,
#  'founded': 622,
#  '450-mile-long': 623,
#  "planters'": 624,
#  'uncourageous': 625,
#  'sunder': 626,
#  'Salisbury': 627,
#  'photographed': 628,
#  'Galophone-Kimberly': 629,
#  'wring': 630,
#  'Newcomers': 631,
#  'commoner': 632,
#  'unwrinkled': 633,
#  'steamily': 634,
#  'stumbling': 635,
#  'Ballroom': 636,
#  'Customers': 637,
#  'left-centerfield': 638,
#  'beveling': 639,
#  'Pm': 640,
#  "transferor's": 641,
#  'geeing': 642,
#  'inventing': 643,
#  'biographer': 644,
#  'may': 645,
#  'grad': 646,
#  'revelatory': 647,
#  'Mis-ter': 648,
#  'ports': 649,
#  'emphasizes': 650,
#  '1638': 651,
#  '156': 652,
#  'Cairo': 653,
#  'Monty': 654,
#  'once-a-month': 655,
#  'wasteful': 656,
#  "Oldenburg's": 657,
#  'enactment': 658,
#  'Prisoners': 659,
#  'reject': 660,
#  '17:07': 661,
#  'Pretender': 662,
#  'orderliness': 663,
#  'maximized': 664,
#  'belongs': 665,
#  'disparagement': 666,
#  '10-foot': 667,
#  'bureaus': 668,
#  'Skid': 669,
#  'lapel': 670,
#  'prick': 671,
#  'Steamboat': 672,
#  'surprising': 673,
#  'vending': 674,
#  'advisory': 675,
#  'Hoijer': 676,
#  'bold': 677,
#  'overeating': 678,
#  'Pre-shaped': 679,
#  'espouses': 680,
#  'scandals': 681,
#  'Manfred': 682,
#  "Needham's": 683,
#  'service-connected': 684,
#  'cave': 685,
#  'heatedly': 686,
#  'Everett': 687,
#  'Clement': 688,
#  'memorizing': 689,
#  '1626': 690,
#  'Noyes': 691,
#  'Shayol': 692,
#  'twelve': 693,
#  'onto': 694,
#  'revamped': 695,
#  'and/or': 696,
#  'low': 697,
#  'extruding': 698,
#  'incline': 699,
#  'gifts': 700,
#  'nightclubs': 701,
#  'Scot': 702,
#  "Dartmouth's": 703,
#  'tunic': 704,
#  'oversimplified': 705,
#  'Wellman': 706,
#  'gobblers': 707,
#  'Whiteman': 708,
#  'stifling': 709,
#  'fortified': 710,
#  'Venus': 711,
#  'supplemental': 712,
#  'Tewfik': 713,
#  'forefeet': 714,
#  'non-fiction': 715,
#  'Gorshek': 716,
#  'initiative': 717,
#  'fellas': 718,
#  'Mudugno': 719,
#  'glorification': 720,
#  'waxy': 721,
#  'organs': 722,
#  'rotenone': 723,
#  'Armed': 724,
#  'Caravaggio': 725,
#  'Hazards': 726,
#  'punched': 727,
#  'wisenheimer': 728,
#  'institutionalized': 729,
#  'mm': 730,
#  'stipulate': 731,
#  'Travelling': 732,
#  'proceed': 733,
#  'undergraduate': 734,
#  'legend': 735,
#  'organised': 736,
#  'trusting': 737,
#  'bogies': 738,
#  'constructively': 739,
#  'ontologically': 740,
#  'Acoustical': 741,
#  'communicational': 742,
#  "Eddie's": 743,
#  'thanking': 744,
#  "Bruckner's": 745,
#  'searing': 746,
#  'backwards': 747,
#  'riddle': 748,
#  'dissembling': 749,
#  'Safavids': 750,
#  'linkage': 751,
#  'turtle': 752,
#  'catching': 753,
#  'halls': 754,
#  '2,200,000': 755,
#  'well-worn': 756,
#  'Dynasts': 757,
#  'density': 758,
#  'strangled': 759,
#  'urethane': 760,
#  'Karipo': 761,
#  'Sinatra': 762,
#  '$18.2': 763,
#  'banished': 764,
#  'ex-mayor': 765,
#  'stallion': 766,
#  'hotel-motel': 767,
#  'equal': 768,
#  'actuate': 769,
#  'evidential': 770,
#  'ex-singer': 771,
#  'Dictator': 772,
#  'Si': 773,
#  "Perier's": 774,
#  'Broadcasters': 775,
#  'bench': 776,
#  'judgments': 777,
#  'stanch': 778,
#  'Unckle': 779,
#  'cartoons': 780,
#  'Acourse': 781,
#  'Deemed': 782,
#  "Soviets'": 783,
#  'Motion-picture': 784,
#  'untruth': 785,
#  'survey-type': 786,
#  'grand': 787,
#  'social-role': 788,
#  "Costaggini's": 789,
#  'Pacific': 790,
#  'retrieve': 791,
#  'McKenzie': 792,
#  'Lauro': 793,
#  'Tiny': 794,
#  'interpeople': 795,
#  'postponement': 796,
#  'world': 797,
#  'sacrificial': 798,
#  'resulted': 799,
#  'shown': 800,
#  'negative': 801,
#  'alerted': 802,
#  'Enjoy': 803,
#  'oust': 804,
#  'shells': 805,
#  '2:04.2': 806,
#  'S.C.': 807,
#  'Traveler': 808,
#  'eyeing': 809,
#  'denuded': 810,
#  'Malamud': 811,
#  'Schuman': 812,
#  'crossover': 813,
#  'mosaic-like': 814,
#  'axes': 815,
#  'muck': 816,
#  'wild-sounding': 817,
#  'nubile': 818,
#  'coalesce': 819,
#  'curriculum': 820,
#  'flung': 821,
#  'Jackson': 822,
#  'stopover': 823,
#  'rows': 824,
#  'paintings': 825,
#  'syllable': 826,
#  'friendly': 827,
#  'Got': 828,
#  '6-7': 829,
#  'legitimate': 830,
#  'competent': 831,
#  'peacemaking': 832,
#  'desecration': 833,
#  'puppyish': 834,
#  'savings': 835,
#  'Bodily': 836,
#  'Membership': 837,
#  'high-rep': 838,
#  'theologian-philosophers': 839,
#  'exhaustion': 840,
#  'indescribable': 841,
#  'H.P.R.': 842,
#  'flown': 843,
#  '11-3': 844,
#  'Dry': 845,
#  'ACTH': 846,
#  'D-night': 847,
#  'Sensibility': 848,
#  'Thieves': 849,
#  'Rensselaerwyck': 850,
#  'actor': 851,
#  'thyrotoxic': 852,
#  'tube': 853,
#  'pathological': 854,
#  'diapiace': 855,
#  'preferring': 856,
#  'cane': 857,
#  'stairways': 858,
#  'interviewee': 859,
#  'Attorney': 860,
#  "rat's": 861,
#  '100-million-lb.': 862,
#  'Effie': 863,
#  'management-trained': 864,
#  'Brendan': 865,
#  'goal-values': 866,
#  'restore': 867,
#  'numenous': 868,
#  'promoting': 869,
#  'neutralized': 870,
#  'stimuli': 871,
#  'Swelling': 872,
#  "'round": 873,
#  'slurries': 874,
#  'imperceptibly': 875,
#  'God-curst': 876,
#  'demography': 877,
#  'Campagnoli': 878,
#  'vagueness': 879,
#  'Throughout': 880,
#  "Hall's": 881,
#  'maria': 882,
#  'Herry': 883,
#  'incoherently': 884,
#  'Schweitzers': 885,
#  'its': 886,
#  'decried': 887,
#  'extenuating': 888,
#  'timeliness': 889,
#  'Bassi': 890,
#  'Wisdom': 891,
#  'diethylstilbestrol': 892,
#  'fronting': 893,
#  'parallel': 894,
#  'brisk': 895,
#  'collonaded': 896,
#  'freedmen': 897,
#  'Opelika': 898,
#  'reading-rooms': 899,
#  'saved': 900,
#  'Christiana': 901,
#  '4:18': 902,
#  'Hidden': 903,
#  'expiation': 904,
#  'believe': 905,
#  'out-of-door': 906,
#  'chimera-chasing': 907,
#  'base-runner': 908,
#  'keeper': 909,
#  'delinquency': 910,
#  'echoed': 911,
#  'rodding': 912,
#  'strumming': 913,
#  'miscellany': 914,
#  'better': 915,
#  'aristocracy': 916,
#  "Wales'": 917,
#  "'emselves": 918,
#  'clean': 919,
#  'ladder': 920,
#  'penman': 921,
#  'twister-coners': 922,
#  'waggled': 923,
#  'weasel-worded': 924,
#  'anytime': 925,
#  'tense': 926,
#  'Trust': 927,
#  'entrusting': 928,
#  'cocktail': 929,
#  'divisions': 930,
#  'Coriolanus': 931,
#  'Bruce': 932,
#  'acquainted': 933,
#  'stare': 934,
#  'ostensible': 935,
#  'Sneed': 936,
#  'spilling': 937,
#  'impropriety': 938,
#  'coconut-containing': 939,
#  'holdovers': 940,
#  'barefooted': 941,
#  'humbly': 942,
#  'Maccabeus': 943,
#  'Tartuffe': 944,
#  'stratum': 945,
#  'Schaeffer': 946,
#  'Committee': 947,
#  'admires': 948,
#  'portraiture': 949,
#  'Magoun': 950,
#  '$84,000,000': 951,
#  'Hundreds': 952,
#  'folk-dance': 953,
#  'sincere': 954,
#  'mansions': 955,
#  'Discussion': 956,
#  'textured': 957,
#  'building': 958,
#  'favoring': 959,
#  'substrates': 960,
#  'wolde': 961,
#  'acculturated': 962,
#  "Ann's": 963,
#  'dilate': 964,
#  'Jussel': 965,
#  '2:20': 966,
#  '29th': 967,
#  'economical': 968,
#  'Dunkel': 969,
#  'restricting': 970,
#  'Dauntless': 971,
#  'Fear-maddened': 972,
#  'long-acting': 973,
#  '463-degrees-C': 974,
#  'disprove': 975,
#  'Kaddish': 976,
#  'God': 977,
#  'confronting': 978,
#  'Maneret': 979,
#  'imperishable': 980,
#  'restitution': 981,
#  'expressionistic': 982,
#  'noncommittal': 983,
#  'veiled': 984,
#  'flourished': 985,
#  'Wife': 986,
#  'low-pass': 987,
#  'Zanzibar': 988,
#  'commercialism': 989,
#  'vertical': 990,
#  'unfortunately': 991,
#  'overlooks': 992,
#  'intimidation': 993,
#  'dusts': 994,
#  'cry': 995,
#  'bestial': 996,
#  'caliche-topped': 997,
#  'Commercants': 998,
#  'inciting': 999,
#  ...}

# %%
tag2idx
# Out:
# {'EX+MD': 0,
#  'RP-NC': 1,
#  "''": 2,
#  'FW-AT+NN-TL': 3,
#  'NN+MD': 4,
#  'DOZ*-TL': 5,
#  'FW-VB-NC': 6,
#  'JJ-TL-NC': 7,
#  'FW-JJT': 8,
#  'ABX': 9,
#  'BEZ': 10,
#  'WPS': 11,
#  'RP-HL': 12,
#  'PPSS': 13,
#  'VB+AT': 14,
#  'PPSS+BEM': 15,
#  'JJT': 16,
#  'PPSS+BER-TL': 17,
#  'FW-*': 18,
#  '(-HL': 19,
#  'FW-AT-HL': 20,
#  'QL-HL': 21,
#  'HV+TO': 22,
#  'PPS+BEZ-HL': 23,
#  'CC-TL-HL': 24,
#  'NP$': 25,
#  ',-HL': 26,
#  'HV-TL': 27,
#  'TO-NC': 28,
#  'NR$': 29,
#  'DOD*': 30,
#  'WQL': 31,
#  'MD-HL': 32,
#  'QL-TL': 33,
#  'NR': 34,
#  'FW-PP$-NC': 35,
#  '.-TL': 36,
#  'DO-TL': 37,
#  'DOD-NC': 38,
#  'NN+IN': 39,
#  'CC-HL': 40,
#  'RB+BEZ': 41,
#  'PP$-TL': 42,
#  'RBT': 43,
#  'BEDZ-NC': 44,
#  'CD-HL': 45,
#  'NPS-TL': 46,
#  'FW-DT+BEZ': 47,
#  "'": 48,
#  'IN-NC': 49,
#  'WPO-NC': 50,
#  'PPL-TL': 51,
#  'RB-TL': 52,
#  'NNS+MD': 53,
#  'OD-TL': 54,
#  'PPS-TL': 55,
#  'DO*': 56,
#  'WRB+MD': 57,
#  'BEM*': 58,
#  'QL': 59,
#  'PPS-NC': 60,
#  'WPS-NC': 61,
#  'VBD-HL': 62,
#  ',-NC': 63,
#  'JJ-TL': 64,
#  'FW-BE': 65,
#  'WRB-TL': 66,
#  'WDT+BEZ-NC': 67,
#  'UH-NC': 68,
#  'DT': 69,
#  'RN': 70,
#  'PN+HVZ': 71,
#  'HVG-HL': 72,
#  'PPL-HL': 73,
#  'FW-WPO': 74,
#  ')-HL': 75,
#  'FW-CD': 76,
#  'EX-HL': 77,
#  'RP-TL': 78,
#  'NP-NC': 79,
#  'JJR-HL': 80,
#  'FW-IN+AT-T': 81,
#  'RB': 82,
#  'FW-OD-TL': 83,
#  'DT-HL': 84,
#  'EX+HVD': 85,
#  'CD-NC': 86,
#  'IN+PPO': 87,
#  '.': 88,
#  'WDT-HL': 89,
#  'FW-CC-TL': 90,
#  'JJR-TL': 91,
#  'NRS': 92,
#  'HVZ-TL': 93,
#  'VBG': 94,
#  'RP': 95,
#  'DT-NC': 96,
#  'CD-TL': 97,
#  'FW-VBZ': 98,
#  'FW-VBD': 99,
#  'WRB+DO': 100,
#  'CC': 101,
#  'FW-NN-NC': 102,
#  'WDT+BEZ-TL': 103,
#  'FW-NN-TL-NC': 104,
#  'NNS$-NC': 105,
#  'JJ': 106,
#  'NP+BEZ-NC': 107,
#  'FW-RB': 108,
#  'PN+BEZ': 109,
#  'PP$-HL': 110,
#  'PPS-HL': 111,
#  'JJR-NC': 112,
#  'JJT-TL': 113,
#  'NPS$-HL': 114,
#  'TO+VB': 115,
#  'CC-TL': 116,
#  ':-HL': 117,
#  'MD+HV': 118,
#  'BEM-NC': 119,
#  'NR-TL': 120,
#  'RBR': 121,
#  '.-HL': 122,
#  'JJ-TL-HL': 123,
#  'CD-TL-HL': 124,
#  ',-TL': 125,
#  'EX+HVZ': 126,
#  'MD+PPSS': 127,
#  'FW-IN+AT': 128,
#  'DO-NC': 129,
#  'VBZ': 130,
#  'WPS+MD': 131,
#  'BER-TL': 132,
#  'MD*-HL': 133,
#  'WPS+HVD': 134,
#  'QL-NC': 135,
#  'FW-IN+NN-TL': 136,
#  'FW-JJR': 137,
#  'FW-AT-TL': 138,
#  'WP$': 139,
#  'FW-UH-TL': 140,
#  'VB': 141,
#  'PPSS+HV': 142,
#  'FW-HV': 143,
#  'NNS$-TL-HL': 144,
#  'FW-UH-NC': 145,
#  'FW-NN$-TL': 146,
#  'FW-RB+CC': 147,
#  'NN+HVZ-TL': 148,
#  'PPO-NC': 149,
#  'MD+TO': 150,
#  'FW-NPS-TL': 151,
#  'FW-WPS': 152,
#  'WRB+DOD': 153,
#  'RP+IN': 154,
#  'NN+HVZ': 155,
#  'VBG+TO': 156,
#  'VB+PPO': 157,
#  '.-NC': 158,
#  'PPSS+BER': 159,
#  'IN-TL-HL': 160,
#  'CC-NC': 161,
#  'AT-TL': 162,
#  'OD-HL': 163,
#  ':': 164,
#  'FW-OD-NC': 165,
#  'FW-BEZ': 166,
#  'NR-NC': 167,
#  'DOZ*': 168,
#  'NP+HVZ-NC': 169,
#  'ABN': 170,
#  'VBN-TL': 171,
#  'HV-NC': 172,
#  'NR-TL-HL': 173,
#  'FW-VB-TL': 174,
#  'BER*': 175,
#  'WPS-HL': 176,
#  'PP$$': 177,
#  'RB+BEZ-NC': 178,
#  'WDT+BER+PP': 179,
#  'WRB-HL': 180,
#  'FW-JJ-TL': 181,
#  'FW-IN+AT-TL': 182,
#  'RB-HL': 183,
#  'VB+RP': 184,
#  'IN': 185,
#  'VB-TL': 186,
#  'PPSS+BER-N': 187,
#  'BER': 188,
#  'WRB-NC': 189,
#  'HVD*': 190,
#  'NNS$-HL': 191,
#  'WDT+BER': 192,
#  'JJS-HL': 193,
#  'VBN+TO': 194,
#  'VBD-TL': 195,
#  'PPSS-NC': 196,
#  'NN+HVD-TL': 197,
#  'WDT+DO+PPS': 198,
#  'DT+BEZ': 199,
#  'FW-NNS-TL': 200,
#  '``': 201,
#  'TO-TL': 202,
#  'DO': 203,
#  'PPSS+VB': 204,
#  'EX+BEZ': 205,
#  'FW-PPS': 206,
#  'NNS-TL-NC': 207,
#  'NP-TL': 208,
#  'AP+AP-NC': 209,
#  'FW-JJ': 210,
#  'FW-DTS': 211,
#  'FW-NR': 212,
#  'ABN-HL': 213,
#  'PPSS+MD': 214,
#  'CS-TL': 215,
#  'CS': 216,
#  'VBN': 217,
#  'TO': 218,
#  'FW-NPS': 219,
#  'PP$': 220,
#  'PN+HVD': 221,
#  'JJT-HL': 222,
#  'FW-NP-TL': 223,
#  'VBG-HL': 224,
#  'WRB+BEZ': 225,
#  'DOZ': 226,
#  'DTX': 227,
#  'FW-PP$': 228,
#  'CD': 229,
#  'NN+NN-NC': 230,
#  'DTS+BEZ': 231,
#  'PPSS+HVD': 232,
#  'JJ-HL': 233,
#  'BE-TL': 234,
#  'VBN-NC': 235,
#  'NPS$-TL': 236,
#  'WDT+BEZ-HL': 237,
#  'DT+MD': 238,
#  'HVZ': 239,
#  'BEN-TL': 240,
#  'BEZ*': 241,
#  'DOZ-HL': 242,
#  'RBR-NC': 243,
#  'NPS$': 244,
#  'PPSS+MD-NC': 245,
#  'FW-RB-TL': 246,
#  'FW-PPO': 247,
#  'FW-PPL+VBZ': 248,
#  'ABL': 249,
#  'WRB+DOD*': 250,
#  'PPS+HVD': 251,
#  'VB+IN': 252,
#  'HV': 253,
#  'FW-NP': 254,
#  'BER*-NC': 255,
#  'FW-VBN': 256,
#  'BER-NC': 257,
#  'VBZ-NC': 258,
#  'FW-TO+VB': 259,
#  'PPSS+HV-TL': 260,
#  'NNS-HL': 261,
#  'PPO-TL': 262,
#  'PPS': 263,
#  'NPS-NC': 264,
#  'NN': 265,
#  'HVD-HL': 266,
#  'IN+IN': 267,
#  'FW-NN-TL': 268,
#  'HVZ*': 269,
#  'IN-TL': 270,
#  'PPLS': 271,
#  'PPO': 272,
#  'WDT+HVZ': 273,
#  'VB-HL': 274,
#  'EX-NC': 275,
#  'PPSS+BEZ*': 276,
#  'HVD': 277,
#  'PP$-NC': 278,
#  'PPSS-HL': 279,
#  'WQL-TL': 280,
#  'FW-JJ-NC': 281,
#  'AT-HL': 282,
#  'DOZ-TL': 283,
#  'FW-AT+NP-TL': 284,
#  'UH': 285,
#  'FW-VBG-TL': 286,
#  'DT+BEZ-NC': 287,
#  'FW-AT': 288,
#  'AT-TL-HL': 289,
#  'NN$': 290,
#  'NP$-TL': 291,
#  'VB+TO': 292,
#  '*-NC': 293,
#  'MD': 294,
#  'JJ-NC': 295,
#  'NN-TL': 296,
#  'BEN': 297,
#  'JJ$-TL': 298,
#  'MD*': 299,
#  'NNS$-TL': 300,
#  'WDT-NC': 301,
#  'FW-NR-TL': 302,
#  'VB-NC': 303,
#  'FW-IN+NN': 304,
#  '*': 305,
#  'AP': 306,
#  'NN$-TL': 307,
#  'PPS+MD': 308,
#  'DTS-HL': 309,
#  'FW-NNS': 310,
#  'VBG-NC': 311,
#  'VBZ-TL': 312,
#  'DO*-HL': 313,
#  'HV*': 314,
#  'HVZ-NC': 315,
#  'AP$': 316,
#  'FW-PN': 317,
#  'WRB+BER': 318,
#  'FW-VBD-TL': 319,
#  'WDT+DOD': 320,
#  'NNS$': 321,
#  'ABN-TL': 322,
#  'DTI-TL': 323,
#  'QLP': 324,
#  'UH-HL': 325,
#  'FW-CC': 326,
#  'PPS+BEZ-NC': 327,
#  'MD-TL': 328,
#  'WRB+BEZ-TL': 329,
#  'VBN-TL-HL': 330,
#  'BE-HL': 331,
#  'RB$': 332,
#  'JJT-NC': 333,
#  'AT-NC': 334,
#  'WDT+BEZ': 335,
#  'PPL-NC': 336,
#  'JJR': 337,
#  'VB+JJ-NC': 338,
#  'ABN-NC': 339,
#  'FW-PPSS': 340,
#  'FW-PPO+IN': 341,
#  'FW-VB': 342,
#  'BEDZ*': 343,
#  'NR-HL': 344,
#  'PN-TL': 345,
#  'VBD-NC': 346,
#  'WPO': 347,
#  'CS-HL': 348,
#  'FW-*-TL': 349,
#  'PPO-HL': 350,
#  'RB-NC': 351,
#  'WDT': 352,
#  'DTI': 353,
#  '*-HL': 354,
#  'WRB+IN': 355,
#  'NNS-NC': 356,
#  'DTI-HL': 357,
#  ',': 358,
#  'RB+CS': 359,
#  'NNS': 360,
#  'DO+PPSS': 361,
#  'BEZ-NC': 362,
#  'FW-NNS-NC': 363,
#  'BEDZ-HL': 364,
#  'HVG': 365,
#  'NP-HL': 366,
#  'NN-NC': 367,
#  'WRB+DOZ': 368,
#  'NP$-HL': 369,
#  'PPS+BEZ': 370,
#  'CD$': 371,
#  ':-TL': 372,
#  'FW-PPSS+HV': 373,
#  'OD': 374,
#  'HV-HL': 375,
#  'BED-NC': 376,
#  'DTS': 377,
#  'HVN': 378,
#  'NP': 379,
#  'FW-IN': 380,
#  'FW-BER': 381,
#  'EX': 382,
#  'FW-UH': 383,
#  'NP+MD': 384,
#  'WPS+BEZ-TL': 385,
#  'BE': 386,
#  'FW-PPL': 387,
#  'NN+BEZ-TL': 388,
#  'NP+HVZ': 389,
#  'NR$-TL': 390,
#  'FW-PP$-TL': 391,
#  'DT-TL': 392,
#  'MD-NC': 393,
#  'CS-NC': 394,
#  'VBZ-HL': 395,
#  'RB+BEZ-HL': 396,
#  'BEDZ': 397,
#  'VBN-TL-NC': 398,
#  'DOD': 399,
#  'BED*': 400,
#  'NN-TL-NC': 401,
#  'PN-HL': 402,
#  '--': 403,
#  'FW-QL': 404,
#  'BER-HL': 405,
#  'VBD': 406,
#  'RBR+CS': 407,
#  '---HL': 408,
#  'BEG': 409,
#  'TO-HL': 410,
#  'AP-HL': 411,
#  'NNS-TL': 412,
#  'NNS-TL-HL': 413,
#  'FW-NN$': 414,
#  'PPS+HVZ': 415,
#  'VBN-HL': 416,
#  'FW-NN': 417,
#  'PN-NC': 418,
#  'FW-VBG': 419,
#  '*-TL': 420,
#  'DOD*-TL': 421,
#  'JJS': 422,
#  'JJR+CS': 423,
#  'DT$': 424,
#  'BEZ-TL': 425,
#  'NIL': 426,
#  'DO-HL': 427,
#  'NN+BEZ': 428,
#  'NP-TL-HL': 429,
#  'IN-HL': 430,
#  'AP-TL': 431,
#  'BEZ-HL': 432,
#  'WPS+HVZ': 433,
#  'JJ+JJ-NC': 434,
#  'JJS-TL': 435,
#  'PPSS+BEZ': 436,
#  'PPSS-TL': 437,
#  'NN$-HL': 438,
#  'PPL': 439,
#  'FW-IN+NP-TL': 440,
#  'BED': 441,
#  'NRS-TL': 442,
#  'NN-TL-HL': 443,
#  'VBG-TL': 444,
#  'WPS+BEZ': 445,
#  'AT': 446,
#  'NPS-HL': 447,
#  'FW-IN-TL': 448,
#  'FW-WDT': 449,
#  'VB+VB-NC': 450,
#  'OD-NC': 451,
#  'PPSS+BER-NC': 452,
#  '(': 453,
#  'PN$': 454,
#  'NN-HL': 455,
#  'WPO-TL': 456,
#  'PN': 457,
#  'NR+MD': 458,
#  'FW-CD-TL': 459,
#  'BEM': 460,
#  'NPS': 461,
#  'PN+MD': 462,
#  ')': 463,
#  'FW-CS': 464,
#  'UH-TL': 465,
#  'AP-NC': 466,
#  'FW-DT': 467,
#  'NP+BEZ': 468,
#  'WRB': 469,
#  'WPS+BEZ-NC': 470,
#  'WPS-TL': 471}

# %%
word_list = [[(word2idx[w]) for (w, _) in sent] for sent in tagged_brown[:20]]

# %%
word_list
# Out:
# [[15403,
#   19855,
#   13021,
#   31271,
#   21434,
#   9002,
#   1457,
#   42930,
#   14906,
#   5206,
#   40089,
#   22610,
#   47037,
#   5906,
#   45814,
#   31751,
#   36868,
#   29199,
#   31429,
#   42393,
#   36488,
#   35187,
#   18108,
#   42001,
#   12317],
#  [15403,
#   21414,
#   1093,
#   9002,
#   39412,
#   41960,
#   24188,
#   42393,
#   25596,
#   17628,
#   32857,
#   947,
#   30361,
#   2979,
#   45250,
#   3527,
#   8868,
#   5206,
#   25596,
#   5906,
#   30361,
#   31751,
#   48841,
#   25596,
#   13024,
#   46750,
#   8844,
#   5206,
#   25596,
#   17628,
#   5206,
#   479,
#   31429,
#   12403,
#   25596,
#   29754,
#   39412,
#   2979,
#   25596,
#   5906,
#   44541,
#   47458,
#   12317],
#  [15403,
#   47097,
#   46734,
#   21414,
#   45250,
#   8752,
#   17891,
#   9290,
#   19855,
#   10279,
#   1863,
#   7999,
#   45081,
#   35224,
#   25181,
#   24706,
#   10411,
#   5206,
#   13090,
#   31751,
#   35187,
#   31429,
#   39412,
#   25596,
#   18195,
#   47037,
#   2979,
#   44541,
#   1549,
#   9290,
#   1289,
#   24364,
#   30255,
#   48206,
#   12317],
#  [31751,
#   42500,
#   39073,
#   41214,
#   42335,
#   5206,
#   11356,
#   10411,
#   44541,
#   20947,
#   31429,
#   30361,
#   25596,
#   21414,
#   9002,
#   30361,
#   31751,
#   20324,
#   25596,
#   39203,
#   22759,
#   39412,
#   25596,
#   5906,
#   30361,
#   25596,
#   53855,
#   5206,
#   26630,
#   46750,
#   25596,
#   11257,
#   5206,
#   11081,
#   43069,
#   31429,
#   12317],
#  [15403,
#   21414,
#   9002,
#   19966,
#   26260,
#   54740,
#   42393,
#   26351,
#   5206,
#   12751,
#   12833,
#   46750,
#   5906,
#   2480,
#   31751,
#   3739,
#   15001,
#   18324,
#   52200,
#   46750,
#   22798,
#   16395,
#   31429,
#   12317],
#  [32143,
#   38984,
#   42393,
#   19855,
#   2265,
#   44747,
#   31751,
#   25181,
#   34632,
#   13789,
#   2480,
#   47241,
#   46750,
#   6316,
#   25181,
#   25596,
#   8970,
#   5206,
#   23159,
#   46750,
#   13659,
#   31852,
#   31429,
#   12317],
#  [15403,
#   787,
#   21414,
#   51184,
#   42253,
#   39073,
#   53855,
#   5206,
#   12685,
#   2119,
#   30361,
#   9756,
#   31852,
#   25596,
#   479,
#   46750,
#   19855,
#   13021,
#   25194,
#   15908,
#   2979,
#   19966,
#   9002,
#   31751,
#   3739,
#   37603,
#   19311,
#   46750,
#   10977,
#   11053,
#   49104,
#   6581,
#   2979,
#   38377,
#   25181,
#   25596,
#   46793,
#   22759,
#   5206,
#   40627,
#   51390,
#   31429,
#   12317],
#  [23503, 54673],
#  [39699,
#   30361,
#   25596,
#   21414,
#   9002,
#   19966,
#   5832,
#   31751,
#   13789,
#   14066,
#   49226,
#   15610,
#   27508,
#   19645,
#   25181,
#   13873,
#   27844,
#   44210,
#   46750,
#   20777,
#   25596,
#   31381,
#   5206,
#   23860,
#   31429,
#   12317],
#  [15403,
#   17628,
#   14279,
#   20957,
#   30361,
#   25596,
#   21414,
#   9002,
#   30361,
#   31751,
#   27773,
#   12838,
#   39412,
#   5785,
#   18173,
#   18191,
#   12976,
#   39073,
#   23579,
#   5206,
#   43069,
#   18191,
#   29543,
#   31429,
#   12317],
#  [32143,
#   3328,
#   42393,
#   25596,
#   43069,
#   31751,
#   34441,
#   17654,
#   25181,
#   19805,
#   31429,
#   11081,
#   17931,
#   12317],
#  [54466,
#   5206,
#   12751,
#   33459,
#   36766,
#   28037,
#   44541,
#   44529,
#   38984,
#   9290,
#   25596,
#   42587,
#   21414,
#   12317],
#  [32143,
#   3328,
#   42393,
#   25596,
#   54576,
#   43601,
#   31751,
#   40847,
#   3201,
#   56054,
#   46750,
#   4155,
#   25596,
#   14529,
#   43395,
#   6643,
#   42393,
#   42930,
#   51715,
#   34530,
#   5206,
#   25596,
#   28037,
#   645,
#   27508,
#   21389,
#   31429,
#   12317],
#  [15403,
#   787,
#   21414,
#   18108,
#   39073,
#   51615,
#   31731,
#   25596,
#   25660,
#   4096,
#   27115,
#   12074,
#   5206,
#   45425,
#   56054,
#   41515,
#   12403,
#   43296,
#   39111,
#   46934,
#   39412,
#   48194,
#   24832,
#   12317],
#  [31751,
#   21282,
#   27773,
#   36117,
#   5206,
#   25596,
#   8723,
#   39996,
#   39412,
#   25596,
#   19855,
#   13021,
#   44763,
#   13612,
#   19744,
#   31429,
#   30361,
#   25596,
#   21414,
#   9002,
#   30361,
#   50239,
#   25596,
#   25660,
#   4096,
#   20957,
#   31751,
#   34360,
#   12154,
#   32016,
#   25181,
#   16876,
#   13789,
#   56054,
#   69,
#   25596,
#   39111,
#   15908,
#   5206,
#   34626,
#   25596,
#   50826,
#   39412,
#   25596,
#   15475,
#   15449,
#   25596,
#   37766,
#   5206,
#   19855,
#   13021,
#   30361,
#   2979,
#   33886,
#   2835,
#   5206,
#   11081,
#   40771,
#   12317],
#  [15403,
#   2166,
#   9002,
#   45164,
#   34227,
#   31751,
#   39073,
#   21086,
#   24031,
#   5206,
#   13789,
#   56054,
#   20033,
#   27623,
#   11081,
#   19744,
#   39412,
#   24916,
#   31447,
#   31877,
#   50826,
#   31429,
#   12317],
#  [30834,
#   30361,
#   31751,
#   6440,
#   7763,
#   42393,
#   39412,
#   25596,
#   34000,
#   19855,
#   13021,
#   15610,
#   41098,
#   301,
#   10098,
#   5206,
#   13789,
#   15835,
#   56054,
#   31429,
#   30361,
#   25596,
#   2166,
#   9002,
#   12317],
#  [31751,
#   5446,
#   25181,
#   42000,
#   11081,
#   14563,
#   39237,
#   25181,
#   42001,
#   39073,
#   160,
#   46471,
#   31429,
#   42253,
#   19855,
#   27199,
#   12317],
#  [15403,
#   21414,
#   44529,
#   51184,
#   42253,
#   25596,
#   19855,
#   42909,
#   35323,
#   2979,
#   34360,
#   8752,
#   50522,
#   53112,
#   12403,
#   886,
#   6581,
#   39412,
#   25596,
#   54029,
#   5206,
#   50980,
#   30361,
#   14593,
#   46750,
#   25148,
#   46750,
#   25596,
#   43582,
#   5206,
#   42594,
#   46750,
#   36342,
#   12317],
#  [6813, 46521]]

# %%
pos_list = [[(tag2idx[t]) for (_, t) in sent] for sent in tagged_brown[:20]]

# %%
pos_list
# Out:
# [[446,
#   208,
#   296,
#   64,
#   296,
#   406,
#   34,
#   446,
#   265,
#   185,
#   25,
#   106,
#   265,
#   265,
#   406,
#   201,
#   446,
#   265,
#   2,
#   216,
#   353,
#   360,
#   406,
#   265,
#   88],
#  [446,
#   265,
#   121,
#   406,
#   185,
#   265,
#   360,
#   216,
#   446,
#   296,
#   64,
#   296,
#   358,
#   352,
#   277,
#   106,
#   265,
#   185,
#   446,
#   265,
#   358,
#   201,
#   130,
#   446,
#   265,
#   101,
#   360,
#   185,
#   446,
#   296,
#   270,
#   208,
#   2,
#   185,
#   446,
#   265,
#   185,
#   352,
#   446,
#   265,
#   397,
#   217,
#   88],
#  [446,
#   379,
#   265,
#   265,
#   277,
#   297,
#   217,
#   185,
#   208,
#   64,
#   296,
#   296,
#   379,
#   379,
#   218,
#   141,
#   360,
#   185,
#   106,
#   201,
#   360,
#   2,
#   185,
#   446,
#   106,
#   265,
#   352,
#   397,
#   217,
#   185,
#   296,
#   379,
#   379,
#   379,
#   88],
#  [201,
#   82,
#   446,
#   106,
#   265,
#   185,
#   106,
#   360,
#   397,
#   217,
#   2,
#   358,
#   446,
#   265,
#   406,
#   358,
#   201,
#   185,
#   446,
#   106,
#   265,
#   185,
#   446,
#   265,
#   358,
#   446,
#   265,
#   185,
#   360,
#   101,
#   446,
#   265,
#   185,
#   69,
#   265,
#   2,
#   88],
#  [446,
#   265,
#   406,
#   263,
#   399,
#   141,
#   216,
#   306,
#   185,
#   25,
#   265,
#   101,
#   265,
#   360,
#   201,
#   188,
#   106,
#   101,
#   106,
#   101,
#   82,
#   106,
#   2,
#   88],
#  [263,
#   406,
#   216,
#   379,
#   360,
#   141,
#   201,
#   218,
#   253,
#   377,
#   360,
#   217,
#   101,
#   217,
#   185,
#   446,
#   265,
#   185,
#   94,
#   101,
#   94,
#   272,
#   2,
#   88],
#  [446,
#   106,
#   265,
#   406,
#   185,
#   446,
#   265,
#   185,
#   306,
#   360,
#   358,
#   185,
#   272,
#   446,
#   379,
#   101,
#   208,
#   296,
#   94,
#   360,
#   352,
#   263,
#   406,
#   201,
#   188,
#   59,
#   217,
#   101,
#   141,
#   82,
#   217,
#   360,
#   352,
#   141,
#   185,
#   446,
#   16,
#   265,
#   185,
#   9,
#   360,
#   2,
#   88],
#  [455, 416],
#  [469,
#   358,
#   446,
#   265,
#   406,
#   263,
#   130,
#   201,
#   377,
#   229,
#   360,
#   294,
#   386,
#   217,
#   218,
#   141,
#   337,
#   265,
#   101,
#   141,
#   446,
#   265,
#   185,
#   265,
#   2,
#   88],
#  [446,
#   296,
#   444,
#   296,
#   358,
#   446,
#   265,
#   406,
#   358,
#   201,
#   10,
#   94,
#   185,
#   217,
#   106,
#   360,
#   216,
#   446,
#   265,
#   185,
#   265,
#   360,
#   360,
#   2,
#   88],
#  [263, 406, 216, 446, 265, 201, 141, 360, 218, 141, 2, 69, 265, 88],
#  [265, 185, 25, 265, 265, 265, 397, 82, 217, 185, 446, 106, 265, 88],
#  [263,
#   406,
#   216,
#   446,
#   306,
#   296,
#   201,
#   141,
#   94,
#   360,
#   101,
#   141,
#   446,
#   106,
#   265,
#   216,
#   216,
#   446,
#   106,
#   265,
#   185,
#   446,
#   265,
#   294,
#   386,
#   217,
#   2,
#   88],
#  [446,
#   106,
#   265,
#   406,
#   446,
#   265,
#   185,
#   446,
#   296,
#   296,
#   307,
#   265,
#   185,
#   106,
#   360,
#   217,
#   185,
#   265,
#   265,
#   360,
#   185,
#   106,
#   360,
#   88],
#  [201,
#   69,
#   10,
#   229,
#   185,
#   446,
#   106,
#   360,
#   185,
#   446,
#   208,
#   296,
#   106,
#   265,
#   265,
#   2,
#   358,
#   446,
#   265,
#   406,
#   358,
#   101,
#   446,
#   296,
#   296,
#   296,
#   201,
#   239,
#   217,
#   106,
#   218,
#   141,
#   377,
#   360,
#   185,
#   446,
#   265,
#   360,
#   185,
#   170,
#   446,
#   360,
#   185,
#   446,
#   265,
#   185,
#   446,
#   265,
#   185,
#   208,
#   296,
#   358,
#   352,
#   130,
#   457,
#   185,
#   69,
#   265,
#   88],
#  [446,
#   360,
#   406,
#   13,
#   141,
#   201,
#   446,
#   106,
#   265,
#   185,
#   377,
#   360,
#   294,
#   141,
#   69,
#   265,
#   185,
#   220,
#   59,
#   106,
#   360,
#   2,
#   88],
#  [82,
#   358,
#   201,
#   13,
#   141,
#   216,
#   185,
#   446,
#   265,
#   208,
#   296,
#   294,
#   141,
#   353,
#   265,
#   185,
#   377,
#   106,
#   360,
#   2,
#   358,
#   446,
#   360,
#   406,
#   88],
#  [201,
#   265,
#   218,
#   203,
#   69,
#   294,
#   141,
#   218,
#   141,
#   446,
#   106,
#   265,
#   2,
#   185,
#   379,
#   360,
#   88],
#  [446,
#   265,
#   82,
#   406,
#   185,
#   446,
#   379,
#   290,
#   265,
#   352,
#   239,
#   297,
#   185,
#   265,
#   185,
#   220,
#   360,
#   185,
#   446,
#   265,
#   185,
#   360,
#   358,
#   360,
#   101,
#   360,
#   101,
#   446,
#   265,
#   185,
#   360,
#   101,
#   265,
#   88],
#  [261, 416]]

# %%
print(word_list[3])
# Out:
# [31751, 42500, 39073, 41214, 42335, 5206, 11356, 10411, 44541, 20947, 31429, 30361, 25596, 21414, 9002, 30361, 31751, 20324, 25596, 39203, 22759, 39412, 25596, 5906, 30361, 25596, 53855, 5206, 26630, 46750, 25596, 11257, 5206, 11081, 43069, 31429, 12317]

# %%
print(pos_list[3])
# Out:
# [201, 82, 446, 106, 265, 185, 106, 360, 397, 217, 2, 358, 446, 265, 406, 358, 201, 185, 446, 106, 265, 185, 446, 265, 358, 446, 265, 185, 360, 101, 446, 265, 185, 69, 265, 2, 88]

# %% [markdown]
# <font size=2 style="color:#2ECC71">**Example**</font>
#
# Another example of a space-time tradeoff is **maintaining a vocabulary list**.
#
# If you need to process an input text to check that all words are in an existing vocabulary, the **vocabulary should be stored as a set, not a list**.
#
# The elements of a set are **automatically indexed**, so testing membership of a large set will be much faster than testing membership of the corresponding list.

# %% [markdown]
# We can test this claim using the `timeit` module.
#
# The `Timer` class has **two parameters**:
#
# - A statement which is executed multiple times;
#
# - setup code that is executed once at the beginning.
#
# We will simulate **a vocabulary of 100,000 items** using a list or set of integers.
#
# The test statement will generate **a random item which has a 50% chance of being in the vocabulary**.

# %%
from timeit import Timer

vocab_size = 100000


setup_list = "import random; vocab = list(range(%d))" % vocab_size
setup_set = "import random; vocab = set(range(%d))" % vocab_size

statement = "random.randint(0, %d) in vocab" % (vocab_size * 2 - 1)

# %%
print(Timer(statement, setup_list).timeit(1000))
# Out:
# 0.8868209280008159

# %%
print(Timer(statement, setup_set).timeit(1000))
# Out:
# 0.0009378600007039495

# %% [markdown]
# ### 4.7.4 Dynamic Programming

# %% [markdown]
# Dynamic programming is **a general technique for designing algorithms** which is widely used in natural language processing.

# %% [markdown]
# Dynamic programming is used when a problem contains **overlapping sub-problems**.
#
# Instead of computing solutions to these sub-problems repeatedly, we simply **store them in a lookup table**.

# %% [markdown]
# In Sanskrit, short syllables, marked S, take up one unit of length, while long syllables, marked L, take two.
#
# 在梵文中，标记为 S 的短音节占据一个长度单位，而标记为 L 的长音节占据两个长度单位

# %% [markdown]
# Figure out the number of ways of combining short and long syllables to create a meter of length $n$.
#
# 找出所有可能的长短音节组合方式，使得组合之后的结果长度为n.

# %% [markdown]
# For example, that there are five ways to construct a meter of length 4: $V4 = \{LL, SSL, SLS, LSS, SSSS\}$.

# %% [markdown]
# we can split $V4$ into two subsets, **those starting with L** and **those starting with S**, as shown in below.

# %% [markdown]
# <pre class="literal-block"><em>V</em><span class="subscript">4</span> =
#   LL, LSS
#     i.e. L prefixed to each item of <em>V</em><span class="subscript">2</span> = {L, SS}
#   SSL, SLS, SSSS
#     i.e. S prefixed to each item of <em>V</em><span class="subscript">3</span> = {SL, LS, SSS}
# </pre>

# %% [markdown]
# **Four Ways** to solve the above problem are shown as below:

# %%
# 1. 递归实现
def virahanka1(n):
    # 第一种基本情况
    if n == 0:
        return [""]
    # 第二种基本情况
    elif n == 1:
        return ["S"]
    else:
        s = ["S" + prosody for prosody in virahanka1(n-1)]
        l = ["L" + prosody for prosody in virahanka1(n-2)]
        return s + l

# %%
virahanka1(4)
# Out:
# ['SSSS', 'SSL', 'SLS', 'LSS', 'LL']

# %%
virahanka1(5)
# Out:
# ['SSSSS', 'SSSL', 'SSLS', 'SLSS', 'SLL', 'LSSS', 'LSL', 'LLS']

# %% [markdown]
# In order to compute V4 we first compute V3 and V2. But to compute V3, we need to first compute V2 and V1. (**repeated computation**) The call structure is as below:

# %% [markdown]
# <div align=center>
# <img width="350" height="350" src="https://www.nltk.org/book/tree_images/ch04-tree-1.png">
# <br>
# <center><em><strong>Call Structure of the Recursion Solution</strong></em></center>
# </div>

# %% [markdown]
# As you can see, V2 is computed twice.
#
# This might not seem like a significant problem, but it turns out to be **rather wasteful as n gets large**:
#
# - To compute V20 using this recursive technique, we would compute V2 **4,181** times;
#
# - For V40 we would compute V2 **63,245,986** times!
#
# <font size=2 style="color:#9B59B6">**Think**</font>:
#
# Please explain the above two statements (why 4,184 and 63,245,986). Fibonacci数列

# %% [markdown]
# A much better alternative is to **store the value of V2 in a table** and look it up whenever we need it.
#
# The same goes for other values, such as V3 and so on.

# %%
# 2. bottom-up dynamic programming
def virahanka2(n):
    # V0, V1
    lookup = [[""], ["S"]]
    
    # n>=2才会执行下面的循环语句
    for i in range(n-1):
        s = ["S" + prosody for prosody in lookup[i+1]]
        l = ["L" + prosody for prosody in lookup[i]]
        lookup.append(s + l)
        
    return lookup[n]

# %% [markdown]
# For example, $n = 3$, the process of the above function is as follow:
#
# $i = 0$, `"S" + lookup[1]`, ---> $V2$
#
# $i = 0$, `"L" + lookup[0]`, ---> $V2$
#
# `lookup = [[""], ["S"], V2]`
#
# $i = 1$, `"S" + lookup[2]`, ---> $V3$
#
# $i = 1$, `"L" + lookup[1]`, ---> $V3$
#
# `lookup = [[""], ["S"], V2, V3]`

# %%
virahanka2(4)
# Out:
# ['SSSS', 'SSL', 'SLS', 'LSS', 'LL']

# %%
virahanka2(5)
# Out:
# ['SSSSS', 'SSSL', 'SSLS', 'SLSS', 'SLL', 'LSSS', 'LSL', 'LLS']

# %%
# 3. top-bottom dynamic programming
def virahanka3(n, lookup={0:[""], 1:["S"]}):
    
    # n>=2下面语句才会执行
    if n not in lookup:
        s = ["S" + prosody for prosody in virahanka3(n-1)]
        l = ["L" + prosody for prosody in virahanka3(n-2)]
        lookup[n] = s + l
    return lookup[n]

# %%
virahanka3(4)
# Out:
# ['SSSS', 'SSL', 'SLS', 'LSS', 'LL']

# %%
virahanka3(5)
# Out:
# ['SSSSS', 'SSSL', 'SSLS', 'SLSS', 'SLL', 'LSSS', 'LSL', 'LLS']

# %%
print(Timer('virahanka3(5)', 'from __main__ import virahanka3').timeit(1))
print(Timer('virahanka1(5)', 'from __main__ import virahanka1').timeit(1))
# Out:
# 3.0129995138850063e-06
# 2.8008998924633488e-05

# %%
print(Timer('virahanka3(30)', 'from __main__ import virahanka3').timeit(1))
print(Timer('virahanka1(30)', 'from __main__ import virahanka1').timeit(1))
# Out:
# 0.3267187269993883
# 2.874420817999635

# %% [markdown]
# For example, $n = 4$, the process of the above function is as follow:
#
# <div align=center>
# <img width="350" height="350" src="https://www.nltk.org/book/tree_images/ch04-tree-1.png">
# <br>
# <center><em><strong>Call Structure of the Top-Bottom Solution</strong></em></center>
# </div>

# %% [markdown]
# 上述自顶向下的递归调用过程虽然与第一种方法一样，但是由于存在一个查找表保存中间计算结果，因此，不存在重复计算，以V2为例，上图左子树中，V3的递归计算过程将V2的结果进行保存，因此，右子树计算V2时，`n not in lookup`的返回结果为`False`，故不会重复V2的递归计算过程。

# %% [markdown]
# Bottom-top turns out to be quite wasteful for some applications, since it may compute solutions to sub-problems that are never required for solving the main problem. (在某些应用中，自底向上的动态规划可能会计算一些对求解主问题没有用的子问题，因而会造成一些资源浪费)
#
# This wasted computation can be avoided using the top-down approach to dynamic programming. (自顶向下的动态规划可以避免这种不必要的资源浪费，因为其首先将主问题逐步分解，仅计算对求解主问题有用的子问题)

# %%
# 4. Python memoize decorator
from nltk import memoize
@memoize
def virahanka4(n):
    if n == 0:
        return [""]
    elif n == 1:
        return ["S"]
    else:
        s = ["S" + prosody for prosody in virahanka4(n-1)]
        l = ["L" + prosody for prosody in virahanka4(n-2)]
        return s + l

# %% [markdown]
# The final method, in virahanka4(), is to use a Python "decorator" called `memoize`. (第四种方法使用了Python的`memoize`装饰器)
#
# This "memoization" process stores the result of each previous call to the function along with the parameters that were used. (该装饰器存储函数调用的结果及对应的参数)
#
#
# If the function is subsequently called with the same parameters, it returns the stored result instead of recalculating it. (当该函数使用同样的参数被调用时，不再重复计算，直接返回存储的结果)

# %% [markdown]
# ## 4.8   A Sample of Python Libraries

# %% [markdown]
# - Matplotlib
#
# - csv
#
# - NetworkX
#
# - Numpy
#
# - Other Python Libraries

# %% [markdown]
# ## 4.9   Summary

# %% [markdown]
# <ul class="simple">
# <li>Python's assignment and parameter passing use object references;
# e.g. if <tt class="doctest"><span class="pre">a</span></tt> is a list and we assign <tt class="doctest"><span class="pre">b = a</span></tt>, then any operation
# on <tt class="doctest"><span class="pre">a</span></tt> will modify <tt class="doctest"><span class="pre">b</span></tt>, and vice versa.</li>
# <li>The <tt class="doctest"><span class="pre"><span class="pysrc-keyword">is</span></span></tt> operation tests if two objects are identical internal objects,
# while <tt class="doctest"><span class="pre">==</span></tt> tests if two objects are equivalent.  This distinction
# parallels the type-token distinction.</li>
# <li>Strings, lists and tuples are different kinds of sequence object, supporting
# common operations such as indexing, slicing, <tt class="doctest"><span class="pre">len()</span></tt>, <tt class="doctest"><span class="pre">sorted()</span></tt>, and
# membership testing using <tt class="doctest"><span class="pre"><span class="pysrc-keyword">in</span></span></tt>.</li>
# <li>A declarative programming style usually produces more compact,
# readable code; manually-incremented loop variables are usually
# unnecessary; when a sequence must be enumerated, use <tt class="doctest"><span class="pre">enumerate()</span></tt>.</li>
# <li>Functions are an essential programming abstraction: key concepts
# to understand are parameter passing, variable scope, and docstrings.</li>
# <li>A function serves as a namespace: names defined inside a function are not visible
# outside that function, unless those names are declared to be global.</li>
# <li>Modules permit logically-related material to be localized in a file.
# A module serves as a namespace: names defined in a module — such as variables
# and functions — are not visible to other modules, unless those names are imported.</li>
# <li>Dynamic programming is an algorithm design technique used widely in NLP
# that stores the results of previous computations in order to avoid
# unnecessary recomputation.</li>
# </ul>

# %%
print("THE END!!!")
# Out:
# THE END!!!
